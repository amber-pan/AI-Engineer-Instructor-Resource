# %% [markdown]
# Lesson 01 Demo 06
# Comparing Numbers Using Python Operators

# %%
# Taking two numbers as input from the user
a = int(input("Enter first number: "))
b = int(input("Enter second number: "))

# Applying comparison operators and displaying results
print(f"{a} > {b}  :", a > b)
print(f"{a} < {b}  :", a < b)
print(f"{a} >= {b} :", a >= b)
print(f"{a} <= {b} :", a <= b)
print(f"{a} == {b} :", a == b)
print(f"{a} != {b} :", a != b)
# Out:
# Failed to start the Kernel.
#
# EPERM: operation not permitted, scandir '/Users/amber/Downloads/course1-Python For AI/OneDrive_1_1-30-2026/0.4_Demos/Lesson_01_Introduction_to_Python_Fundamentals_and_Setup'.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.
